# %%
N = int(input())
A = list(map(int, input().split()))
A_sorted = sorted(A)
kinds = list(set(A_sorted))
kinds_s = sorted(kinds)
dis = 0
change_points = [0]
for i in range(N - 1):
    if A_sorted[i] != A_sorted[i + 1]:
        change_points.append(i + 1)
change_points.append(len(A_sorted))
dis = 0
for j in range(len(kinds_s)):
    val = kinds_s[j]
    cnt = change_oints[j + 1] - change_points[j]
    if cnt >= val:
        dis += cnt - val
    else:
        dis += cnt
print(dis)
# Out:
# 2

# %%
print(change_points)
# Out:
# [0, 1, 3, 5]

# %%
print(kinds_s)
# Out:
# [1, 2, 4]

# %%
print(A)
# Out:
# [1, 2, 2, 3, 3, 3]

# %%
N = int(input())
A = list(map(int, input().split()))
A.sort()
A_ori = []
cnt = 1
if len(A) > 1:
    for i in range(N - 1):
        if A[i + 1] == A[i]:
            cnt += 1
            if i + 1 == N - 1:
                A_ori.append([A[i], cnt])
        else:
            A_ori.append([A[i], cnt])
            cnt = 1
else:
    A_ori.append([A[0], cnt])
#print(A_ori)
max_val = 0
if len(A_ori) > 2:
    for j in range(len(A_ori) - 2):
        val = A_ori[j][1] + A_ori[j + 1][1] + A_ori[j + 2][1]
        if max_val < val:
            max_val = val
elif len(A_ori) == 2:
    max_val = A_ori[0][1] + A_ori[1][1]
else:
    max_val = A_ori[0][1]

    
print(max_val)
# Out:
# 5

# %%
print(A_ori)
# Out:
# []
