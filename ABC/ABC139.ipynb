# %%
N = int(input())
ans = 0
for i in range(1, N):
    ans += i
print(ans)
# Out:
# 0

# %%
A, B = map(int, input().split())
for i in range(100):
    if 1 + (A - 1) * i >= B:
        print(i)
        break
# Out:
# 4
