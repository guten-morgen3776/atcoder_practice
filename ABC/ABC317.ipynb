# %%
N, M = map(int, input().split())
roads = []
length = []
for _ in range(M):
    a, b, c = map(int, input().split())
    roads.append([a, b])
    length.append(c)

def dfs(s):
    if goal[s]:
        return
