# %%
a, b, c = map(int, input().split())

a1 = a * 100 + b * 10 + c
a2 = a * 100 + c * 10 + b
a3 = b * 100 + a * 10 + c
a4 = b * 100 + c * 10 + a
a5 = c * 100 + a * 10 + b
a6 = c * 100 + b * 10 + a

print(max(a1, a2, a3, a4, a5, a6))
# Out:
# 432

# %%
X = list(map(int, input()))
X_sort = sorted(X)
min_num = [0] * (len(X))
if min(X) > 0:
    ans = X_sort
    ans = list(map(str, ans))
    print(''.join(ans))
else:
    min_idx = 0
    for i in range(len(X_sort)):
        if X_sort[i] > 0:
            min_idx = i 
            break
    X_sort[0], X_sort[i] = X_sort[i], X_sort[0]
    ans = X_sort
    ans = list(map(str, ans))
    print(''.join(ans))
# Out:
# 309

# %%
N, X, Y = map(int, input().split())
A = list(map(int, input().split()))
K = Y - X
Am = min(A)
AM = max(A)
R = (A[0] * X) % K
if X * AM > (K + X) * Am:
    print(-1)
else:
    for i in range(N):
        if (A[i] * X) % K != R:
            print(-1)
            break
    else:
        W_min = X * AM
        W_max = Y * Am
        w = W_max - ((W_max - R) % K)
        if w < W_min:
            print(-1)
        else:
            ans = (N * w - sum(A) * X) // K
            print(ans)
# Out:
# -1
