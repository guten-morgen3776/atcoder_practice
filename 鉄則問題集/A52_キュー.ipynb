# %%
Q = int(input())
from collections import deque
q = deque()
for _ in range(Q):
    que = list(input().split())
    if int(que[0]) == 1:
        q.append(que[1])
    elif int(que[0]) == 2:
        print(q[0])
    else:
        q.popleft()
# Out:
# taro
# hanako
