# %%
Q = int(input())
map = {}
for _ in range(Q):
    que = list(input().split())

    if int(que[0]) == 1:
        map[que[1]] = que[2]
    else:
        print(map[que[1]])
# Out:
# ['1', 'tanaka', '49']
# ['1', 'suzuki', '50']
# ['2', 'tanaka']
# 49

# %%
print(map)
map['tanaka']
# Out:
# {'tanaka': '49', 'suzuki': '50'}
# '49'
